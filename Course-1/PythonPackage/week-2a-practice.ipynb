# %%
import src.edhec_risk_kit as erk
import pandas as pd
import matplotlib
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

#To avoid scientific notation display
pd.options.display.float_format = '{:.5f}'.format

#To reset, un-comment the following
#pd.reset_option

# %%
ind = erk.read_ind_returns(data_loc='./data')

# %%
ind.head()
# Out:
#             Food     Beer   Smoke    Games    Books    Hshld    Clths  \
# 1926-07  0.00560 -0.05190 0.01290  0.02930  0.10970 -0.00480  0.08080
# 1926-08  0.02590  0.27030 0.06500  0.00550  0.10010 -0.03580 -0.02510
# 1926-09  0.01160  0.04020 0.01260  0.06580 -0.00990  0.00730 -0.00510
# 1926-10 -0.03060 -0.03310 0.01060 -0.04760  0.09470 -0.04680  0.00120
# 1926-11  0.06350  0.07290 0.04550  0.01660 -0.05800 -0.00540  0.01870
#
#             Hlth    Chems   Txtls   ...       Telcm    Servs    BusEq  \
# 1926-07  0.01770  0.08140 0.00390   ...     0.00830  0.09220  0.02060
# 1926-08  0.04250  0.05500 0.08140   ...     0.02170  0.02020  0.04390
# 1926-09  0.00690  0.05330 0.02310   ...     0.02410  0.02250  0.00190
# 1926-10 -0.00570 -0.04760 0.01000   ...    -0.00110 -0.02000 -0.01090
# 1926-11  0.05420  0.05200 0.03110   ...     0.01630  0.03770  0.03640
#
#            Paper    Trans    Whlsl    Rtail    Meals      Fin    Other
# ...

# %%
erk.drawdown(ind["Food"])["Drawdown"].plot.line(figsize=(12,6))

# %%
erk.var_gaussian(ind, modified=True, level = .05).sort_values(ascending=True).plot.bar()

# %%
erk.sharpe_ratio(ind,0.03).sort_values().plot.bar()

# %%
erk.sharpe_ratio(ind["2000":], 0.03).sort_values().plot.bar(title='Industry Sharpe Ratios since 2000')

# %%
ind.index[0]
# Out:
# Period('1926-07', 'M')
